# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv("esquistossomose.csv")

# %%
tabela
# Out:
#       TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP
# 0          2      B659    20180101   201801    2018         31      310620  \
# 1          2      B659    20180102   201801    2018         31      315210
# 2          2      B659    20180102   201801    2018         31      312270
# 3          2      B659    20180102   201801    2018         26      260830
# 4          2      B659    20180102   201801    2018         32      320130
# ...      ...       ...         ...      ...     ...        ...         ...
# 4214       2      B659    20181228   201852    2018         31      310620
# 4215       2      B659    20181228   201852    2018         26      261160
# 4216       2      B659    20181229   201852    2018         31      313130
# 4217       2      B659    20181230   201901    2018         32      320435
# 4218       2      B659    20181231   201901    2018         31      310620
#
#      ID_REGIONA  ID_UNIDADE  DT_SIN_PRI  ...  DT_TRANSSM DT_TRANSRS
# 0      1449           22659    20171229  ...    20180607             \
# 1      1458         2218038    20171201  ...    20180111
# 2      1458         6300219    20171207  ...    20180215
# 3      1500         6511465    20171226  ...
# 4      1510         2546892    20171205  ...
# ...         ...         ...         ...  ...         ...        ...
# 4214   1449           23183    20181005  ...    20190221
# 4215   1497             655    20181120  ...
# 4216   1468         2205440    20181001  ...
# 4217   1509         2494353    20181226  ...    20190624
# 4218   1449           23892    20181231  ...    20190110
#
#       DT_TRANSSE  DT_OBITO                        DS_FORMA AN_QUALI    DTTRAT
# 0                                                                    20180115  \
# 1                                                                 1  20180102
# 2                                                                 1  20180102
# 3                                                                 1  20180108
# 4                                                                 1  20180102
# ...          ...       ...                             ...      ...       ...
# 4214                        NAO INFORMADA                         3  20181228
# 4215
# 4216                                                              2  20181030
# 4217                                                              1  20190102
# 4218                                                                 20181231
#
#       DT_RESU3                                  OUTRO_EX IDADE
# 0     20180425  KATO-KATZ POSITIVO                        55.0
# 1                                                         30.0
# 2                                                         33.0
# 3                                                         52.0
# 4                                                         46.0
# ...        ...                                       ...   ...
# 4214            BIOPSIA RETAL PESQUISA DE OVOS DO  SCHIS  39.0
# 4215                                                      16.0
# 4216            IMUNOFLUORESCENCIA                        52.0
# 4217  20190522  PARASITOLOGICO                            59.0
# 4218            EXAME LABORATORIO PRIVADO                 33.0
#
# [4219 rows x 54 columns]

# %%
tabela.keys()
# Out:
# Index(['TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'SG_UF_NOT',
#        'ID_MUNICIP', 'ID_REGIONA', 'ID_UNIDADE', 'DT_SIN_PRI', 'SEM_PRI',
#        'ANO_NASC', 'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA',
#        'CS_ESCOL_N', 'SG_UF', 'ID_MN_RESI', 'ID_RG_RESI', 'ID_PAIS',
#        'DT_INVEST', 'ID_OCUPA_N', 'DT_COPRO', 'AN_QUANT', 'OUTROS', 'TRATAM',
#        'TRATANAO', 'STCURA1', 'STCURA2', 'STCURA3', 'FORMA', 'TPAUTOCTO',
#        'COUFINF', 'COPAISINF', 'COMUNINF', 'NOPROPIN', 'NOCOLINF',
#        'DOENCA_TRA', 'EVOLUCAO', 'DT_ENCERRA', 'DT_DIGITA', 'DT_TRANSUS',
#        'DT_TRANSDM', 'DT_TRANSSM', 'DT_TRANSRS', 'DT_TRANSSE', 'DT_OBITO',
#        'DS_FORMA', 'AN_QUALI', 'DTTRAT', 'DT_RESU3', 'OUTRO_EX', 'IDADE'],
#       dtype='object')

# %% [markdown]
# # Questão 2

# %%
def questao_2(datapath):
    tabela = pd.read_csv(datapath)
    return tabela.value_counts("ID_MUNICIP")

# %%
questao_2("esquistossomose.csv")
# Out:
# ID_MUNICIP
# 313130    419
# 310620    353
# 355030    173
# 310050    166
# 312270    127
#          ...
# 310900      1
# 310690      1
# 310510      1
# 310040      1
# 313220      1
# Name: count, Length: 598, dtype: int64

# %% [markdown]
# # Questão 4

# %%
def questao_4(datapath):
    tabela = pd.read_csv(datapath)
    return tabela["IDADE"].mean()

# %%
questao_4("esquistossomose.csv")
# Out:
# 40.20773257745728

# %% [markdown]
# # Questão 5

# %%
def questao_5(datapath):
    tabela = pd.read_csv(datapath)
    tabela_por_estado = tabela.value_counts("SG_UF_NOT")
    codigos_estados = {35: 'SP', 41: 'PR', 42: 'SC', 43: 'RS', 50: 'MS', 11: 'RO', 12: 'AC', 13: 'AM', 14: 'RR', 15: 'PA', 16: 'AP', 17: 'TO', 21: 'MA', 24: 'RN', 25: 'PB', 26: 'PE', 27: 'AL', 28: 'SE', 29: 'BA', 31: 'MG', 33: 'RJ', 51: 'MT', 52: 'GO', 53: 'DF', 22: 'PI', 23: 'CE', 32: 'ES'}
    print(tabela_por_estado)
    for codigo, sigla in codigos_estados.items():
        tabela_por_estado.rename(index = {codigo: sigla}, inplace = True)
    return tabela_por_estado.to_dict()

# %%
questao_5("esquistossomose.csv")
# Out:
# SG_UF_NOT
# 31    2064
# 35     573
# 32     437
# 29     341
# 26     177
# 28     130
# 27     102
# 11      66
# 21      54
# 41      49
# 25      46
# 33      44
# 23      37
# 53      24
# 42      12
# 52      12
# 51      11
# 24      11
# 50       9
# 15       8
# 17       4
# 14       3
# 16       2
# 43       2
# 22       1
# Name: count, dtype: int64
# {'MG': 2064,
#  'SP': 573,
#  'ES': 437,
#  'BA': 341,
#  'PE': 177,
#  'SE': 130,
#  'AL': 102,
#  'RO': 66,
#  'MA': 54,
#  'PR': 49,
#  'PB': 46,
#  'RJ': 44,
#  'CE': 37,
#  'DF': 24,
#  'SC': 12,
#  'GO': 12,
#  'MT': 11,
#  'RN': 11,
#  'MS': 9,
#  'PA': 8,
#  'TO': 4,
#  'RR': 3,
#  'AP': 2,
#  'RS': 2,
#  'PI': 1}

# %% [markdown]
# # Questão 6

# %%
def questao_6(datapath):
    tabela = pd.read_csv(datapath)
    sexo_masculino = tabela[tabela["CS_SEXO"] == "M"]
    sexo_masculino_por_estado = sexo_masculino.value_counts("SG_UF_NOT")
    codigos_estados = {35: 'SP', 41: 'PR', 42: 'SC', 43: 'RS', 50: 'MS', 11: 'RO', 12: 'AC', 13: 'AM', 14: 'RR', 15: 'PA', 16: 'AP', 17: 'TO', 21: 'MA', 24: 'RN', 25: 'PB', 26: 'PE', 27: 'AL', 28: 'SE', 29: 'BA', 31: 'MG', 33: 'RJ', 51: 'MT', 52: 'GO', 53: 'DF', 22: 'PI', 23: 'CE', 32: 'ES'}
    for codigo, sigla in codigos_estados.items():
        sexo_masculino_por_estado.rename(index = {codigo: sigla}, inplace = True)
    return sexo_masculino_por_estado.to_dict()

# %%
questao_6("esquistossomose.csv")
# Out:
# {'MG': 1276,
#  'SP': 312,
#  'ES': 307,
#  'BA': 191,
#  'PE': 100,
#  'SE': 78,
#  'AL': 50,
#  'PR': 41,
#  'RO': 36,
#  'MA': 35,
#  'PB': 27,
#  'RJ': 26,
#  'CE': 19,
#  'SC': 12,
#  'DF': 11,
#  'GO': 8,
#  'RN': 7,
#  'MS': 7,
#  'MT': 6,
#  'PA': 4,
#  'TO': 2,
#  'RR': 1,
#  'AP': 1,
#  'RS': 1}

# %% [markdown]
# # Questão 8

# %%
DATA = "esquistossomose.parquet"

# %%
def questao_8(datapath = DATA):
    tabela = pd.read_parquet(datapath)
    tabela["DT_NOTIFICACAO"] = pd.to_datetime(tabela["DT_NOTIFIC"])
    tabela["DT_SINTOMAS"] = pd.to_datetime(tabela["DT_SIN_PRI"])
    tabela["ATRASO_NOT"] = tabela["DT_NOTIFICACAO"] - tabela["DT_SINTOMAS"]
    return tabela[["DT_NOTIFICACAO", "DT_SINTOMAS", "ATRASO_NOT"]]

# %%
questao_8()
# Out:
#      DT_NOTIFICACAO DT_SINTOMAS ATRASO_NOT
# 0        2018-01-01  2017-12-29     3 days
# 1        2018-01-02  2017-12-01    32 days
# 2        2018-01-02  2017-12-07    26 days
# 3        2018-01-02  2017-12-26     7 days
# 4        2018-01-02  2017-12-05    28 days
# ...             ...         ...        ...
# 4214     2018-12-28  2018-10-05    84 days
# 4215     2018-12-28  2018-11-20    38 days
# 4216     2018-12-29  2018-10-01    89 days
# 4217     2018-12-30  2018-12-26     4 days
# 4218     2018-12-31  2018-12-31     0 days
#
# [4219 rows x 3 columns]

# %% [markdown]
# # Questão 7

# %%
tabela = pd.read_parquet("esquistossomose.parquet")
mun_por_est = {31: 853, 35: 645, 43: 497, 29: 417, 41 : 399, 42 : 295, 52 : 246, 22 : 224, 25 : 223, 21: 217, 26 : 184, 23 : 184, 24 : 167, 15 : 144, 51 : 141, 17 : 139, 27 : 102, 33 : 92, 50 : 79, 32 : 78, 28 : 75, 13 : 62,11 : 52, 12 : 22, 16 : 16, 14 : 15, 53:1}
codigos_estados = {35: 'SP', 41: 'PR', 42: 'SC', 43: 'RS', 50: 'MS', 11: 'RO', 12: 'AC', 13: 'AM', 14: 'RR', 15: 'PA', 16: 'AP', 17: 'TO', 21: 'MA', 24: 'RN', 25: 'PB', 26: 'PE', 27: 'AL', 28: 'SE', 29: 'BA', 31: 'MG', 33: 'RJ', 51: 'MT', 52: 'GO', 53: 'DF', 22: 'PI', 23: 'CE', 32: 'ES'}
cidades_com_casos_por_estado = tabela.groupby('SG_UF_NOT')['ID_MUNICIP'].nunique()

for codigo, sigla in codigos_estados.items():
    cidades_com_casos_por_estado.rename(index = {codigo: sigla}, inplace = True)

print(cidades_com_casos_por_estado)
# Out:
# SG_UF_NOT
# 11     11
# 14      2
# 15      5
# 16      2
# 17      3
# 21      8
# 22      1
# 23     11
# 24      4
# 25     13
# 26     32
# 27     31
# 28     24
# 29     94
# 31    152
# 32     33
# 33     15
# 35    106
# 41     19
# 42     10
# 43      2
# 50      5
# 51      5
# 52      9
# 53      1
# Name: ID_MUNICIP, dtype: int64

# %%
proporcao = {}

for estado, cidades_com_casos in cidades_com_casos_por_estado.items():
    proporcao[int(estado)] = round((cidades_com_casos*100/(mun_por_est[int(estado)])), 2)

print(proporcao)
# Out:
# {11: 21.15, 14: 13.33, 15: 3.47, 16: 12.5, 17: 2.16, 21: 3.69, 22: 0.45, 23: 5.98, 24: 2.4, 25: 5.83, 26: 17.39, 27: 30.39, 28: 32.0, 29: 22.54, 31: 17.82, 32: 42.31, 33: 16.3, 35: 16.43, 41: 4.76, 42: 3.39, 43: 0.4, 50: 6.33, 51: 3.55, 52: 3.66, 53: 100.0}

# %% [markdown]
# # Questão 10

# %%
atraso = pd.read_parquet("esquistossomose.parquet")
atraso["DT_NOTIFICACAO"] = pd.to_datetime(atraso["DT_NOTIFIC"])
atraso["DT_SINTOMAS"] = pd.to_datetime(atraso["DT_SIN_PRI"])
atraso["ATRASO_NOT"] = atraso["DT_NOTIFICACAO"] - atraso["DT_SINTOMAS"]
atraso["ATRASO_NOT"] = atraso["ATRASO_NOT"].dt.days

atraso
# Out:
#      TP_NOT ID_AGRAVO DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP
# 0         2      B659   20180101  201801   2018        31     310620  \
# 1         2      B659   20180102  201801   2018        31     315210
# 2         2      B659   20180102  201801   2018        31     312270
# 3         2      B659   20180102  201801   2018        26     260830
# 4         2      B659   20180102  201801   2018        32     320130
# ...     ...       ...        ...     ...    ...       ...        ...
# 4214      2      B659   20181228  201852   2018        31     310620
# 4215      2      B659   20181228  201852   2018        26     261160
# 4216      2      B659   20181229  201852   2018        31     313130
# 4217      2      B659   20181230  201901   2018        32     320435
# 4218      2      B659   20181231  201901   2018        31     310620
#
#      ID_REGIONA ID_UNIDADE DT_SIN_PRI  ...  DT_OBITO
# 0      1449        0022659   20171229  ...            \
# 1      1458        2218038   20171201  ...
# 2      1458        6300219   20171207  ...
# 3      1500        6511465   20171226  ...
# 4      1510        2546892   20171205  ...
# ...         ...        ...        ...  ...       ...
# 4214   1449        0023183   20181005  ...
# 4215   1497        0000655   20181120  ...
# 4216   1468        2205440   20181001  ...
# 4217   1509        2494353   20181226  ...
# 4218   1449        0023892   20181231  ...
#
#                             DS_FORMA AN_QUALI    DTTRAT  DT_RESU3
# 0                                              20180115  20180425  \
# 1                                           1  20180102
# 2                                           1  20180102
# 3                                           1  20180108
# 4                                           1  20180102
# ...                              ...      ...       ...       ...
# 4214  NAO INFORMADA                         3  20181228
# 4215
# 4216                                        2  20181030
# 4217                                        1  20190102  20190522
# 4218                                           20181231
#
#                                       OUTRO_EX DT_NOTIFICACAO IDADE
# 0     KATO-KATZ POSITIVO                           2018-01-01  55.0  \
# 1                                                  2018-01-02  30.0
# 2                                                  2018-01-02  33.0
# 3                                                  2018-01-02  52.0
# 4                                                  2018-01-02  46.0
# ...                                        ...            ...   ...
# 4214  BIOPSIA RETAL PESQUISA DE OVOS DO  SCHIS     2018-12-28  39.0
# 4215                                               2018-12-28  16.0
# 4216  IMUNOFLUORESCENCIA                           2018-12-29  52.0
# 4217  PARASITOLOGICO                               2018-12-30  59.0
# 4218  EXAME LABORATORIO PRIVADO                    2018-12-31  33.0
#
#      DT_SINTOMAS ATRASO_NOT
# 0     2017-12-29          3
# 1     2017-12-01         32
# 2     2017-12-07         26
# 3     2017-12-26          7
# 4     2017-12-05         28
# ...          ...        ...
# 4214  2018-10-05         84
# 4215  2018-11-20         38
# 4216  2018-10-01         89
# 4217  2018-12-26          4
# 4218  2018-12-31          0
#
# [4219 rows x 57 columns]

# %%
atraso_por_municipio = pd.DataFrame(atraso.groupby("ID_MUNICIP")["ATRASO_NOT"].agg(["count", "mean"]))
atraso_por_municipio
# Out:
#             count         mean
# ID_MUNICIP
# 110002          1    95.000000
# 110005          2     0.000000
# 110011         16    12.750000
# 110015         19  1130.368421
# 110020         11    22.272727
# ...           ...          ...
# 521720          1    31.000000
# 521740          1    86.000000
# 521880          1   155.000000
# 522050          2     8.000000
# 530010         24   254.000000
#
# [598 rows x 2 columns]

# %%
plt.scatter(atraso_por_municipio["mean"], atraso_por_municipio["count"])
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
def questao_10(datapath = DATA):
    atraso = pd.read_parquet(datapath)
    atraso["DT_NOTIFICACAO"] = pd.to_datetime(atraso["DT_NOTIFIC"])
    atraso["DT_SINTOMAS"] = pd.to_datetime(atraso["DT_SIN_PRI"])
    atraso["ATRASO_NOT"] = atraso["DT_NOTIFICACAO"] - atraso["DT_SINTOMAS"]
    atraso["ATRASO_NOT"] = atraso["ATRASO_NOT"].dt.days
    atraso_por_municipio = pd.DataFrame(atraso.groupby("ID_MUNICIP")["ATRASO_NOT"].agg(["count", "mean"]))

    plt.scatter(atraso_por_municipio["mean"], atraso_por_municipio["count"])
    plt.xscale("log")
    plt.yscale("log")
    plt.show()

    return atraso.groupby("ID_MUNICIP")["ATRASO_NOT"].mean()

# %%
questao_10()
# Out:
# ID_MUNICIP
# 110002      95.000000
# 110005       0.000000
# 110011      12.750000
# 110015    1130.368421
# 110020      22.272727
#              ...
# 521720      31.000000
# 521740      86.000000
# 521880     155.000000
# 522050       8.000000
# 530010     254.000000
# Name: ATRASO_NOT, Length: 598, dtype: float64
